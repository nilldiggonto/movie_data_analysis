# %%
#Budget and Revenue are co related or not

# %%
#Import lib

# %%
import pandas as pd

# %%
#Loading data

# %%
movie = pd.read_csv('files/movies_metadata.csv', low_memory=False) #kaggle.com

# %%
movie
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
 #cleaning data

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
### converting datetime

# %%
pd.to_datetime(movie['release_date'],errors='coerce') #error='coerce' help to put 'Nat' where datatime cant convert
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45461          NaT
# 45462   2011-11-17
# 45463   2003-08-01
# 45464   1917-10-21
# 45465   2017-06-09
# Name: release_date, Length: 45466, dtype: datetime64[ns]

# %%
movie =movie.set_index(pd.to_datetime(movie['release_date'],errors='coerce'))

# %%
movie
# Out:
#               adult                              belongs_to_collection  \
# release_date
# 1995-10-30    False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1995-12-15    False                                                NaN
# 1995-12-22    False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 1995-12-22    False                                                NaN
# 1995-02-10    False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...             ...                                                ...
# NaT           False                                                NaN
# 2011-11-17    False                                                NaN
# 2003-08-01    False                                                NaN
# 1917-10-21    False                                                NaN
# 2017-06-09    False                                                NaN
#
#                 budget                                             genres  \
# release_date
# ...

# %%
movie.drop(columns='release_date',inplace=True)

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45466 entries, 1995-10-30 to 2017-06-09
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
movie.sort_index(inplace=True)

# %%
movie.head(20)
# Out:
#               adult belongs_to_collection budget  \
# release_date
# 1874-12-09    False                   NaN      0
# 1878-06-14    False                   NaN      0
# 1883-11-19    False                   NaN      0
# 1887-08-18    False                   NaN      0
# 1888-01-01    False                   NaN      0
# 1888-10-15    False                   NaN      0
# 1890-01-01    False                   NaN      0
# 1890-03-09    False                   NaN      0
# 1890-11-21    False                   NaN      0
# 1890-11-21    False                   NaN      0
# 1890-11-21    False                   NaN      0
# 1891-01-01    False                   NaN      0
# 1891-01-01    False                   NaN      0
# 1891-01-02    False                   NaN      0
# 1891-04-30    False                   NaN      0
# 1891-05-01    False                   NaN      0
# 1891-11-15    False                   NaN      0
# 1892-01-01    False                   NaN      0
# ...

# %%
movie.tail()
# Out:
#               adult belongs_to_collection budget  \
# release_date
# NaT           False                   NaN      0
# NaT           False                   NaN      0
# NaT           False                   NaN      0
# NaT           False                   NaN      0
# NaT           False                   NaN      0
#
#                                                          genres  \
# release_date
# NaT                                                          []
# NaT           [{'id': 9648, 'name': 'Mystery'}, {'id': 878, ...
# NaT                                                          []
# NaT           [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# NaT           [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
#
#                                           homepage      id    imdb_id  \
# release_date
# NaT                                            NaN  438910  tt0810384
# NaT                                            NaN  433711  tt3158690
# ...

# %%
data = movie.loc[:,['title','budget','revenue']].copy()

# %%
movie[['title','budget','revenue']]
# Out:
#                                                        title budget  revenue
# release_date
# 1874-12-09                                  Passage of Venus      0      0.0
# 1878-06-14                        Sallie Gardner at a Gallop      0      0.0
# 1883-11-19                                   Buffalo Running      0      0.0
# 1887-08-18                       Man Walking Around a Corner      0      0.0
# 1888-01-01                                  Accordion Player      0      0.0
# ...                                                      ...    ...      ...
# NaT                                          Engineering Red      0      0.0
# NaT           All Superheroes Must Die 2: The Last Superhero      0      0.0
# NaT                           The Land Where the Blues Began      0      0.0
# NaT                                                    Aprel      0      0.0
# NaT                                                   Subdue      0      0.0
#
# [45466 rows x 3 columns]

# %%
data
# Out:
#                                                        title budget  revenue
# release_date
# 1874-12-09                                  Passage of Venus      0      0.0
# 1878-06-14                        Sallie Gardner at a Gallop      0      0.0
# 1883-11-19                                   Buffalo Running      0      0.0
# 1887-08-18                       Man Walking Around a Corner      0      0.0
# 1888-01-01                                  Accordion Player      0      0.0
# ...                                                      ...    ...      ...
# NaT                                          Engineering Red      0      0.0
# NaT           All Superheroes Must Die 2: The Last Superhero      0      0.0
# NaT                           The Land Where the Blues Began      0      0.0
# NaT                                                    Aprel      0      0.0
# NaT                                                   Subdue      0      0.0
#
# [45466 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45466 entries, 1874-12-09 to NaT
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    45460 non-null  object
#  1   budget   45466 non-null  object
#  2   revenue  45460 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.4+ MB

# %%
data['budget'] = pd.to_numeric(data['budget'],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45466 entries, 1874-12-09 to NaT
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    45460 non-null  object
#  1   budget   45463 non-null  float64
#  2   revenue  45460 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#              budget       revenue
# count  4.546300e+04  4.546000e+04
# mean   4.224579e+06  1.120935e+07
# std    1.742413e+07  6.433225e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    3.800000e+08  2.787965e+09

# %%
##
data.iloc[:,-2:] = data.iloc[:,-2:] / 1000000

# %%
data
# Out:
#                                                        title  budget  revenue
# release_date
# 1874-12-09                                  Passage of Venus     0.0      0.0
# 1878-06-14                        Sallie Gardner at a Gallop     0.0      0.0
# 1883-11-19                                   Buffalo Running     0.0      0.0
# 1887-08-18                       Man Walking Around a Corner     0.0      0.0
# 1888-01-01                                  Accordion Player     0.0      0.0
# ...                                                      ...     ...      ...
# NaT                                          Engineering Red     0.0      0.0
# NaT           All Superheroes Must Die 2: The Last Superhero     0.0      0.0
# NaT                           The Land Where the Blues Began     0.0      0.0
# NaT                                                    Aprel     0.0      0.0
# NaT                                                   Subdue     0.0      0.0
#
# ...

# %%
data.describe()
# Out:
#              budget       revenue
# count  45463.000000  45460.000000
# mean       4.224579     11.209349
# std       17.424133     64.332247
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max      380.000000   2787.965087

# %%
## mean= average budget for movie is 4.2 million and revenue is 11.2 million

# %%
#max movie budget is 380 million and revenue is 2.7 billion us dollar

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45466 entries, 1874-12-09 to NaT
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    45460 non-null  object
#  1   budget   45463 non-null  float64
#  2   revenue  45460 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 1.4+ MB

# %%
#working with missing values

# %%
data.loc[data['title'].isna()] # these are movies that dont have any title budget or release date
# Out:
#              title  budget  revenue
# release_date
# NaT            NaN     0.0      NaN
# NaT            NaN     NaN      NaN
# NaT            NaN     0.0      NaN
# NaT            NaN     NaN      NaN
# NaT            NaN     0.0      NaN
# NaT            NaN     NaN      NaN

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45460 entries, 1874-12-09 to NaT
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    45460 non-null  object
#  1   budget   45460 non-null  float64
#  2   revenue  45460 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 1.4+ MB

# %%
data['budget'].value_counts()
# Out:
# 0.000000     36570
# 5.000000       286
# 10.000000      259
# 20.000000      243
# 2.000000       242
#              ...
# 9.364800         1
# 4.180000         1
# 36.500000        1
# 0.011178         1
# 6.854500         1
# Name: budget, Length: 1223, dtype: int64

# %%
data['revenue'].value_counts()
# Out:
# 0.000000     38052
# 12.000000       20
# 10.000000       19
# 11.000000       19
# 2.000000        18
#              ...
# 11.083449        1
# 7.644937         1
# 24.188922        1
# 29.918745        1
# 8.801940         1
# Name: revenue, Length: 6863, dtype: int64

# %%
## there are movies where budge is 0 and revenue is 0 which is not a correct data

# %%
#filter dataFrame

# %%
data = data.loc[(data['revenue']>0) & (data['budget']>0)]

# %%
data
# Out:
#                                      title     budget     revenue
# release_date
# 1915-02-08           The Birth of a Nation   0.100000   11.000000
# 1915-12-13                       The Cheat   0.017311    0.137365
# 1916-12-24    20,000 Leagues Under the Sea   0.200000    8.000000
# 1918-08-01                          Mickey   0.250000    8.000000
# 1921-01-21                         The Kid   0.250000    2.500000
# ...                                    ...        ...         ...
# 2017-07-26                   Atomic Blonde  30.000000   90.007945
# 2017-07-28                 The Emoji Movie  50.000000   66.913939
# 2017-08-03                  The Dark Tower  60.000000   71.000000
# 2017-08-03                      Wind River  11.000000  184.770205
# 2017-08-04                          Kidnap  21.000000   24.527158
#
# [5381 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5381 entries, 1915-02-08 to 2017-08-04
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    5381 non-null   object
#  1   budget   5381 non-null   float64
#  2   revenue  5381 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 168.2+ KB

# %%
data.describe()
# Out:
#             budget      revenue
# count  5381.000000  5381.000000
# mean     31.094796    90.318123
# std      40.162625   166.142264
# min       0.000001     0.000001
# 25%       5.037000     7.011317
# 50%      17.000000    29.918745
# 75%      40.000000    99.965753
# max     380.000000  2787.965087

# %%
data.sort_values('budget',ascending=False)
# Out:
#                                                     title      budget  \
# release_date
# 2011-05-14    Pirates of the Caribbean: On Stranger Tides  380.000000
# 2007-05-19       Pirates of the Caribbean: At World's End  300.000000
# 2015-04-22                        Avengers: Age of Ultron  280.000000
# 2006-06-28                               Superman Returns  270.000000
# 2012-03-07                                    John Carter  260.000000
# ...                                                   ...         ...
# 1987-11-06                                 Less Than Zero    0.000001
# 2012-03-30                                 Aquí Entre Nos    0.000001
# 1936-02-05                                   Modern Times    0.000001
# 2003-08-15                                      Tere Naam    0.000001
# 2003-05-05                                          Saamy    0.000001
#
#                   revenue
# release_date
# 2011-05-14    1045.713802
# 2007-05-19     961.000000
# ...

# %%
data.sort_values('revenue',ascending=False)
# Out:
#                                      title      budget      revenue
# release_date
# 2009-12-10                          Avatar  237.000000  2787.965087
# 2015-12-15    Star Wars: The Force Awakens  245.000000  2068.223624
# 1997-11-18                         Titanic  200.000000  1845.034188
# 2012-04-25                    The Avengers  220.000000  1519.557910
# 2015-06-09                  Jurassic World  150.000000  1513.528810
# ...                                    ...         ...          ...
# 2003-08-15                       Tere Naam    0.000001     0.000002
# 1995-09-28                    Mute Witness    0.000002     0.000001
# 1996-10-16         The Wind in the Willows    0.000012     0.000001
# 1925-08-26                 The Merry Widow    0.000592     0.000001
# 2015-12-04                     The Letters    0.000001     0.000001
#
# [5381 rows x 3 columns]

# %%
data.to_csv('budget_revenue_2017.csv')
