# %%
#Linear regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette='rainbow')

# %%
import scipy.stats as stats
np.set_printoptions(precision=2,suppress=True)

# %%
data = pd.read_csv('budget_revenue_2017.csv',parse_dates=['release_date'],index_col='release_date')

# %%
data.head()
# Out:
#                                      title    budget    revenue
# release_date
# 1915-02-08           The Birth of a Nation  0.100000  11.000000
# 1915-12-13                       The Cheat  0.017311   0.137365
# 1916-12-24    20,000 Leagues Under the Sea  0.200000   8.000000
# 1918-08-01                          Mickey  0.250000   8.000000
# 1921-01-21                         The Kid  0.250000   2.500000

# %%
##getting only data for 2016

# %%
data_16 = data.loc['2016']

# %%
data_16
# Out:
#                                                   title  budget     revenue
# release_date
# 2016-01-01                               Jane Got a Gun    25.0    1.397284
# 2016-01-07                               Friend Request     9.9    2.400000
# 2016-01-07                                   The Forest    10.0   40.055439
# 2016-01-07                                        Wazir     5.2    9.200000
# 2016-01-13    13 Hours: The Secret Soldiers of Benghazi    50.0   69.411370
# ...                                                 ...     ...         ...
# 2016-12-23             Resident Evil: The Final Chapter    40.0  312.242626
# 2016-12-23                              Railroad Tigers    50.0  102.205175
# 2016-12-23                                       Dangal    10.4  310.000000
# 2016-12-25                                Live by Night   108.0   22.678555
# 2016-12-25                           20th Century Women     7.0    5.816211
#
# [235 rows x 3 columns]

# %%
#### visualize data
sns.lmplot(data=data_16,x='budget',y='revenue',height=8,ci=None)
plt.show()

# %%
#linear regression with numpy

# %%
x = data_16.iloc[:,-2].values #budget

# %%
y = data_16.iloc[:,-1].values #revenue

# %%
regression_m = np.polyfit(x=x,y=y,deg=1)
regression_m
# Out:
# array([ 3.35, -9.45])

# %%
np.polyfit(x=data_16['budget'],y=data_16['revenue'],deg=1)
# Out:
# array([ 3.35, -9.45])

# %%
### creating numpy x and y values for regression

# %%
X1 = np.array([min(x),max(x)])

# %%
X1
# Out:
# array([  0., 250.])

# %%
Y1 = np.polyval(regression_m,X1)

# %%
Y1
# Out:
# array([ -9.45, 827.91])

# %%
##

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y)
plt.scatter(x=x,y=y)
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.show()

# %%
####### with scipy

# %%
stats.linregress(x=data_16['budget'],y=data_16['revenue'])
# Out:
# LinregressResult(slope=3.34942409884989, intercept=-9.449215053886647, rvalue=0.8001327462030166, pvalue=1.2387431075239183e-53, stderr=0.16449519793934372)
